# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sqlite3
import pickle
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from collections import defaultdict
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, SimpleRNN, Activation
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Flatten
from tensorflow.keras import backend as K
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from keras.models import load_model
import re

# %%
conn = sqlite3.connect(r'C:\Users\kenta\OneDrive\Desktop\Platinum Binar\database.db', check_same_thread=False)
query = 'SELECT * FROM new_data'
data = pd.read_sql_query (query, conn)
data.head()
# Out:
#                                                Tweet     Label
# 0  warung ini dimiliki oleh pengusaha pabrik tahu...  positive
# 1  mohon ulama lurus dan k mmbri hujjah partai ap...   neutral
# 2  lokasi strategis di jalan sumatra bandung temp...  positive
# 3  betapa bahagia nya diri ini saat unboxing pake...  positive
# 4  aduh jadi mahasiswa jangan sombong dong kasih ...  negative

# %%
# Membagi data berdasarkan label
data_dict = {}
for label in ['positive', 'neutral', 'negative']:
    data_dict[label] = data[data['Label'] == label]

# Menentukan jumlah sampel yang sama dari data 'neutral' dan 'negative'
sample_size = max(data_dict['neutral'].shape[0], data_dict['negative'].shape[0])

# Menggabungkan data
data = pd.concat([data_dict['positive'], data_dict['neutral'].sample(sample_size, replace=True), data_dict['negative']])

# Membuat list Tweet dan Label
tweet_dict = {}
label_dict = {}

for label in ['positive', 'neutral', 'negative']:
    tweet_dict[label] = data[data['Label'] == label].Tweet.tolist()
    label_dict[label] = data[data['Label'] == label].Label.tolist()

# %%
total_tweets_assemble = tweet_dict['positive'] + tweet_dict['negative'] + tweet_dict['neutral']

labels = label_dict['positive'] + label_dict['negative'] + label_dict['neutral']

print("Jumlah Value Positive: %s, Jumlah Value Neutral: %s, Jumlah Value Negative: %s" % (len(tweet_dict['positive']), len(tweet_dict['negative']), 
                                                   len(tweet_dict['neutral'])))
print("Total data text: %s" % len(total_data))
print("Total labels: %s" % len(labels))
# Out:
# Jumlah Value Positive: 6383, Jumlah Value Neutral: 3412, Jumlah Value Negative: 3412
# Total data text: 13207
# Total labels: 13207

# %% [markdown]
# Feature Extraction
#
# Pemanfaatan tokenizer untuk melakukan ekstraksi data agar mudah diproses dalam modeling data.

# %%
max_features_tokenize = 100000
data_tokenizer = Tokenizer(num_words=max_features_tokenize, split=' ', lower=True)
data_tokenizer.fit_on_texts(total_tweets_assemble)

#Penyimpanan data TokenizerFile kedalam pickle
with open('TokenizerFile.pickle', 'wb') as file:
    pickle.dump(data_tokenizer, file , protocol=pickle.HIGHEST_PROTOCOL)
    print('File "TokenizerFile.pickle" telah tercetak!')
# Out:
# File "TokenizerFile.pickle" telah tercetak!

# %%
#Feature Extraction of X data
X = data_tokenizer.texts_to_sequences(total_tweets_assemble)
maxlen = max(len(x) for x in X)
X = pad_sequences(X)

#Penyimpanan data x_pad_sequences kedalam pickle
with open('x_pad_sequences.pickle', 'wb') as file:
    pickle.dump(X, file , protocol=pickle.HIGHEST_PROTOCOL)
    print('File "x_pad_sequences.pickle" telah tercetak!')


#Feature Extraction of Y data
y = pd.get_dummies(labels)
y = y.values

#Penyimpanan data x_target kedalam library pickle
with open('x_target.pickle', 'wb') as file:
    pickle.dump(y, file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# File "x_pad_sequences.pickle" telah tercetak!

# %% [markdown]
# Train-Test Split Data

# %%
#Split train-test dataset
#Loading Dataset
x_file = open('x_pad_sequences.pickle', 'rb')
x = pickle.load(x_file)
x_file.close()

y_file = open('x_target.pickle', 'rb')
y = pickle.load(y_file)
y_file.close()

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.3, random_state=42)

# %%
#Pelatihan model menggunakan Train-Test Split
model = Sequential()
model.add(Embedding(max_features_tokenize, output_dim = 100, input_length = x.shape[1] ))
model.add(LSTM(units= 64, dropout=0.2))
model.add(Dense(units=y.shape[1], activation= 'softmax'))
model.compile(loss = 'binary_crossentropy', optimizer='adam', metrics = ['accuracy'])
print(model.summary())

adam_optim = optimizers.Adam(learning_rate = 0.0001)
model.compile(loss = 'categorical_crossentropy', optimizer = adam_optim, metrics = ['accuracy'])

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
history = model.fit(x_train, y_train, epochs=20, batch_size=32, 
                        validation_data=(x_test, y_test), verbose=1, callbacks=[es])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 85, 100)           10000000
#
#  lstm_2 (LSTM)               (None, 64)                42240
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 10042435 (38.31 MB)
# Trainable params: 10042435 (38.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/20
# 289/289 [==============================] - 33s 107ms/step - loss: 0.8940 - accuracy: 0.6142 - val_loss: 0.7032 - val_accuracy: 0.6768
# Epoch 2/20
# 289/289 [==============================] - 30s 104ms/step - loss: 0.6396 - accuracy: 0.6983 - val_loss: 0.5657 - val_accuracy: 0.7613
# Epoch 3/20
# 289/289 [==============================] - 30s 104ms/step - loss: 0.4985 - accuracy: 0.8082 - val_loss: 0.4563 - val_accuracy: 0.8244
# Epoch 4/20
# 289/289 [==============================] - 30s 105ms/step - loss: 0.3716 - accuracy: 0.8788 - val_loss: 0.3649 - val_accuracy: 0.8764
# Epoch 5/20
# 289/289 [==============================] - 30s 104ms/step - loss: 0.2830 - accuracy: 0.9038 - val_loss: 0.3184 - val_accuracy: 0.8872
# Epoch 6/20
# 289/289 [==============================] - 30s 102ms/step - loss: 0.2276 - accuracy: 0.9236 - val_loss: 0.2956 - val_accuracy: 0.8933
# Epoch 7/20
# 289/289 [==============================] - 30s 103ms/step - loss: 0.1864 - accuracy: 0.9378 - val_loss: 0.2909 - val_accuracy: 0.8976
# Epoch 8/20
# 289/289 [==============================] - 30s 103ms/step - loss: 0.1571 - accuracy: 0.9479 - val_loss: 0.2801 - val_accuracy: 0.8981
# Epoch 9/20
# 289/289 [==============================] - 30s 104ms/step - loss: 0.1336 - accuracy: 0.9579 - val_loss: 0.2981 - val_accuracy: 0.8950
# Epoch 10/20
# 289/289 [==============================] - 30s 104ms/step - loss: 0.1132 - accuracy: 0.9643 - val_loss: 0.2981 - val_accuracy: 0.8996
# Epoch 10: early stopping

# %%
def create_model():
    model = Sequential()
    model.add(Embedding(max_features_tokenize, embed_dim, input_length=X.shape[1]))
    model.add(LSTM(units, dropout=0.5))
    model.add(Dense(3, activation='softmax'))
    adam = optimizers.Adam(learning_rate=0.0005)
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

def train_model(model, data_train, target_train, data_test, target_test):
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
    history = model.fit(data_train, target_train, epochs=50, batch_size=32, 
                        validation_data=(data_test, target_test), verbose=1, callbacks=[es])
    return model

# Inisialisasi KFold
kf = KFold(n_splits=5, random_state=42, shuffle=True)
accuracies = []


embed_dim = 100
units = 64

# Iterasi melalui lipatan (folds) KFold
for iteration, data in enumerate(kf.split(X), start=1):
    data_train, target_train = X[data[0]], y[data[0]]
    data_test, target_test = X[data[1]], y[data[1]]

    model = create_model()
    trained_model = train_model(model, data_train, target_train, data_test, target_test)

    # Prediksi
    predictions = trained_model.predict(x_test)
    y_pred = predictions

    # Menghitung akurasi
    accuracy = accuracy_score(y_test.argmax(axis=1), y_pred.argmax(axis=1))

    # Menampilkan hasil
    print(f"Iterasi ke-{iteration}")
    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1)))
    print("======================================================")

    accuracies.append(accuracy)

# Menghitung rata-rata akurasi
average_accuracy = np.mean(accuracies)

print("\n\n\n")
print("Rata-rata Akurasi:", round(average_accuracy, 4))
# Out:
# Epoch 1/50
# 331/331 [==============================] - 39s 109ms/step - loss: 0.6324 - accuracy: 0.7338 - val_loss: 0.3561 - val_accuracy: 0.8785
# Epoch 2/50
# 331/331 [==============================] - 36s 110ms/step - loss: 0.2786 - accuracy: 0.9024 - val_loss: 0.2619 - val_accuracy: 0.9027
# Epoch 3/50
# 331/331 [==============================] - 34s 102ms/step - loss: 0.1718 - accuracy: 0.9409 - val_loss: 0.2412 - val_accuracy: 0.9031
# Epoch 4/50
# 331/331 [==============================] - 35s 105ms/step - loss: 0.1252 - accuracy: 0.9584 - val_loss: 0.2388 - val_accuracy: 0.9126
# Epoch 5/50
# 331/331 [==============================] - 32s 97ms/step - loss: 0.0892 - accuracy: 0.9705 - val_loss: 0.2653 - val_accuracy: 0.9080
# Epoch 6/50
# 331/331 [==============================] - 34s 104ms/step - loss: 0.0691 - accuracy: 0.9760 - val_loss: 0.3047 - val_accuracy: 0.9076
# Epoch 6: early stopping
# 124/124 [==============================] - 3s 15ms/step
# Iterasi ke-1
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88      1040
#            1       0.97      0.98      0.98       958
#            2       0.92      0.96      0.94      1965
#
#     accuracy                           0.93      3963
#    macro avg       0.94      0.93      0.93      3963
# weighted avg       0.93      0.93      0.93      3963
#
# ======================================================
# Epoch 1/50
# 331/331 [==============================] - 38s 105ms/step - loss: 0.6296 - accuracy: 0.7363 - val_loss: 0.3908 - val_accuracy: 0.8558
# Epoch 2/50
# 331/331 [==============================] - 34s 103ms/step - loss: 0.2853 - accuracy: 0.8986 - val_loss: 0.2779 - val_accuracy: 0.9035
# Epoch 3/50
# 331/331 [==============================] - 36s 110ms/step - loss: 0.1795 - accuracy: 0.9373 - val_loss: 0.2640 - val_accuracy: 0.9046
# Epoch 4/50
# 331/331 [==============================] - 37s 112ms/step - loss: 0.1241 - accuracy: 0.9565 - val_loss: 0.2550 - val_accuracy: 0.9114
# Epoch 5/50
# 331/331 [==============================] - 37s 112ms/step - loss: 0.0900 - accuracy: 0.9690 - val_loss: 0.3069 - val_accuracy: 0.9122
# Epoch 6/50
# 331/331 [==============================] - 35s 107ms/step - loss: 0.0720 - accuracy: 0.9746 - val_loss: 0.2971 - val_accuracy: 0.9114
# Epoch 6: early stopping
# 124/124 [==============================] - 2s 15ms/step
# Iterasi ke-2
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94      1040
#            1       0.97      0.99      0.98       958
#            2       0.98      0.95      0.96      1965
#
#     accuracy                           0.96      3963
#    macro avg       0.96      0.96      0.96      3963
# weighted avg       0.96      0.96      0.96      3963
#
# ======================================================
# Epoch 1/50
# 331/331 [==============================] - 38s 106ms/step - loss: 0.6638 - accuracy: 0.7164 - val_loss: 0.3946 - val_accuracy: 0.8413
# Epoch 2/50
# 331/331 [==============================] - 33s 100ms/step - loss: 0.3050 - accuracy: 0.8906 - val_loss: 0.3001 - val_accuracy: 0.8856
# Epoch 3/50
# 331/331 [==============================] - 34s 102ms/step - loss: 0.1851 - accuracy: 0.9372 - val_loss: 0.2637 - val_accuracy: 0.8989
# Epoch 4/50
# 331/331 [==============================] - 39s 117ms/step - loss: 0.1287 - accuracy: 0.9553 - val_loss: 0.3017 - val_accuracy: 0.8940
# Epoch 5/50
# 331/331 [==============================] - 36s 108ms/step - loss: 0.0951 - accuracy: 0.9670 - val_loss: 0.2906 - val_accuracy: 0.8978
# Epoch 5: early stopping
# 124/124 [==============================] - 2s 16ms/step
# Iterasi ke-3
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      1040
#            1       1.00      1.00      1.00       958
#            2       0.99      0.97      0.98      1965
#
#     accuracy                           0.98      3963
#    macro avg       0.98      0.98      0.98      3963
# weighted avg       0.98      0.98      0.98      3963
#
# ======================================================
# Epoch 1/50
# 331/331 [==============================] - 41s 112ms/step - loss: 0.6431 - accuracy: 0.7195 - val_loss: 0.3910 - val_accuracy: 0.8535
# Epoch 2/50
# 331/331 [==============================] - 38s 115ms/step - loss: 0.2879 - accuracy: 0.8973 - val_loss: 0.2956 - val_accuracy: 0.8981
# Epoch 3/50
# 331/331 [==============================] - 36s 109ms/step - loss: 0.1784 - accuracy: 0.9398 - val_loss: 0.2807 - val_accuracy: 0.8989
# Epoch 4/50
# 331/331 [==============================] - 38s 115ms/step - loss: 0.1228 - accuracy: 0.9564 - val_loss: 0.2765 - val_accuracy: 0.8993
# Epoch 5/50
# 331/331 [==============================] - 37s 112ms/step - loss: 0.0889 - accuracy: 0.9690 - val_loss: 0.2920 - val_accuracy: 0.9031
# Epoch 6/50
# 331/331 [==============================] - 35s 107ms/step - loss: 0.0733 - accuracy: 0.9734 - val_loss: 0.3304 - val_accuracy: 0.8981
# Epoch 6: early stopping
# 124/124 [==============================] - 3s 17ms/step
# Iterasi ke-4
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1040
#            1       0.99      1.00      1.00       958
#            2       0.99      0.98      0.98      1965
#
#     accuracy                           0.98      3963
#    macro avg       0.98      0.98      0.98      3963
# weighted avg       0.98      0.98      0.98      3963
#
# ======================================================
# Epoch 1/50
# 331/331 [==============================] - 38s 108ms/step - loss: 0.6332 - accuracy: 0.7440 - val_loss: 0.3720 - val_accuracy: 0.8675
# Epoch 2/50
# 331/331 [==============================] - 36s 107ms/step - loss: 0.2810 - accuracy: 0.8989 - val_loss: 0.2782 - val_accuracy: 0.9046
# Epoch 3/50
# 331/331 [==============================] - 36s 109ms/step - loss: 0.1810 - accuracy: 0.9384 - val_loss: 0.2590 - val_accuracy: 0.9106
# Epoch 4/50
# 331/331 [==============================] - 36s 108ms/step - loss: 0.1241 - accuracy: 0.9567 - val_loss: 0.2624 - val_accuracy: 0.9159
# Epoch 5/50
# 331/331 [==============================] - 36s 110ms/step - loss: 0.0970 - accuracy: 0.9663 - val_loss: 0.2552 - val_accuracy: 0.9205
# Epoch 6/50
# 331/331 [==============================] - 35s 106ms/step - loss: 0.0782 - accuracy: 0.9722 - val_loss: 0.3116 - val_accuracy: 0.8970
# Epoch 7/50
# 331/331 [==============================] - 34s 103ms/step - loss: 0.0629 - accuracy: 0.9781 - val_loss: 0.2966 - val_accuracy: 0.9114
# Epoch 7: early stopping
# 124/124 [==============================] - 2s 15ms/step
# Iterasi ke-5
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1040
#            1       1.00      1.00      1.00       958
#            2       0.99      0.98      0.99      1965
#
#     accuracy                           0.99      3963
#    macro avg       0.99      0.99      0.99      3963
# weighted avg       0.99      0.99      0.99      3963
#
# ======================================================
#
#
#
#
# Rata-rata Akurasi: 0.9692

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 6))

    # Plot Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'g', label='Training Acc')
    plt.plot(epochs, val_acc, 'y', label='Validation Acc')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    sns.despine()

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'g', label='Training Loss')
    plt.plot(epochs, val_loss, 'y', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    sns.despine()

    plt.tight_layout()
    plt.show()

# Memanggil fungsi plot_history untuk memvisualisasikan hasil
plot_history(history)

# %%
#Save model
trained_model.save('model.h5')
print('Model has created')
# Out:
# Model has created

# %%
input_text = """Dia memakan kue dengan lahap dan beringas jelek"""
def cleansing(text):
    text = text.lower()
    text = re.sub(r'((www\.[^\s]+)|(https?://[^\s]+)|(http?://[^\s]+))', ' ', text)
    text = re.sub(r'pic.twitter.com.[\w]+', ' ', text)
    text = re.sub(r'[^a-z\s]', ' ', text)
    text = text.replace('user', '')
    text = re.sub(' +', ' ', text)
    text = text.replace('\n', ' ')
    return text

sentiment = ['negative', 'neutral', 'positive']

text = [cleansing(input_text)]
predicted = data_tokenizer.texts_to_sequences(text)
guess = pad_sequences(predicted, maxlen=X.shape[1])

model = load_model('model.h5')
prediction = model.predict(guess)
polarity = np.argmax(prediction[0])
hasil = sentiment[polarity]

print("Text: %s" % text[0])
print("Sentiment: %s" % sentiment[polarity])
# Out:
# WARNING:tensorflow:5 out of the last 128 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001AEDEAF23E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 409ms/step
# Text: dia memakan kue dengan lahap dan beringas jelek enak
# Sentiment: negative
