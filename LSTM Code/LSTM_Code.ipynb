# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sqlite3
import pickle
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from collections import defaultdict
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, SimpleRNN, Activation
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import Flatten
from tensorflow.keras import backend as K
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from keras.models import load_model
import re

# %%
conn = sqlite3.connect(r'C:\Users\kenta\OneDrive\Desktop\Platinum Binar\database.db', check_same_thread=False)
query = 'SELECT * FROM new_data'
data = pd.read_sql_query (query, conn)
data.head()
# Out:
#                                                Tweet     Label
# 0  warung dimiliki pengusaha pabrik puluhan terke...  positive
# 1  mohon ulama lurus k mmbri hujjah partai diwlh ...   neutral
# 2  lokasi strategis jalan sumatra bandung nyaman ...  positive
# 3  betapa bahagia unboxing paket barang bagus men...  positive
# 4  aduh mahasiswa sombong kasih kartu kuning bela...  negative

# %%
# Membagi data berdasarkan label
data_dict = {}
for label in ['positive', 'neutral', 'negative']:
    data_dict[label] = data[data['Label'] == label]

# Menentukan jumlah sampel yang sama dari data 'neutral' dan 'negative'
sample_size = max(data_dict['neutral'].shape[0], data_dict['negative'].shape[0])

# Menggabungkan data
data = pd.concat([data_dict['positive'], data_dict['neutral'].sample(sample_size, replace=True), data_dict['negative']])

# Membuat list Tweet dan Label
tweet_dict = {}
label_dict = {}

for label in ['positive', 'neutral', 'negative']:
    tweet_dict[label] = data[data['Label'] == label].Tweet.tolist()
    label_dict[label] = data[data['Label'] == label].Label.tolist()

# %%
total_tweets_assemble = tweet_dict['positive'] + tweet_dict['negative'] + tweet_dict['neutral']

labels = label_dict['positive'] + label_dict['negative'] + label_dict['neutral']

print("Jumlah Value Positive: %s, Jumlah Value Neutral: %s, Jumlah Value Negative: %s" % (len(tweet_dict['positive']), len(tweet_dict['negative']), 
                                                   len(tweet_dict['neutral'])))
print("Total data text: %s" % len(total_tweets_assemble))
print("Total labels: %s" % len(labels))
# Out:
# Jumlah Value Positive: 6383, Jumlah Value Neutral: 3412, Jumlah Value Negative: 3412
# Total data text: 13207
# Total labels: 13207

# %% [markdown]
# Feature Extraction
#
# Pemanfaatan tokenizer untuk melakukan ekstraksi data agar mudah diproses dalam modeling data.

# %%
max_features_tokenize = 100000
data_tokenizer = Tokenizer(num_words=max_features_tokenize, split=' ', lower=True)
data_tokenizer.fit_on_texts(total_tweets_assemble)

#Penyimpanan data TokenizerFile kedalam pickle
with open('TokenizerFile.pickle', 'wb') as file:
    pickle.dump(data_tokenizer, file , protocol=pickle.HIGHEST_PROTOCOL)
    print('File "TokenizerFile.pickle" telah tercetak!')
# Out:
# File "TokenizerFile.pickle" telah tercetak!

# %%
#Feature Extraction of X data
X = data_tokenizer.texts_to_sequences(total_tweets_assemble)
maxlen = max(len(x) for x in X)
X = pad_sequences(X)

#Penyimpanan data x_pad_sequences kedalam pickle
with open('x_pad_sequences.pickle', 'wb') as file:
    pickle.dump(X, file , protocol=pickle.HIGHEST_PROTOCOL)
    print('File "x_pad_sequences.pickle" telah tercetak!')


#Feature Extraction of Y data
y = pd.get_dummies(labels)
y = y.values

#Penyimpanan data x_target kedalam library pickle
with open('x_target.pickle', 'wb') as file:
    pickle.dump(y, file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# File "x_pad_sequences.pickle" telah tercetak!

# %% [markdown]
# Train-Test Split Data

# %%
#Split train-test dataset
#Loading Dataset
x_file = open('x_pad_sequences.pickle', 'rb')
x = pickle.load(x_file)
x_file.close()

y_file = open('x_target.pickle', 'rb')
y = pickle.load(y_file)
y_file.close()

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.3, random_state=42)

# %%
#Pelatihan model menggunakan Train-Test Split
model = Sequential()
model.add(Embedding(max_features_tokenize, output_dim = 100, input_length = x.shape[1] ))
model.add(LSTM(units= 64, dropout=0.2))
model.add(Dense(units=y.shape[1], activation= 'softmax'))
model.compile(loss = 'binary_crossentropy', optimizer='adam', metrics = ['accuracy'])
print(model.summary())

adam_optim = optimizers.Adam(learning_rate = 0.0001)
model.compile(loss = 'categorical_crossentropy', optimizer = adam_optim, metrics = ['accuracy'])

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
history1 = model.fit(x_train, y_train, epochs=20, batch_size=32, 
                        validation_data=(x_test, y_test), verbose=1, callbacks=[es])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 55, 100)           10000000
#
#  lstm (LSTM)                 (None, 64)                42240
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 10042435 (38.31 MB)
# Trainable params: 10042435 (38.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/20
# 289/289 [==============================] - 28s 90ms/step - loss: 0.9327 - accuracy: 0.5884 - val_loss: 0.7403 - val_accuracy: 0.6576
# Epoch 2/20
# 289/289 [==============================] - 25s 85ms/step - loss: 0.6827 - accuracy: 0.6820 - val_loss: 0.6188 - val_accuracy: 0.7068
# Epoch 3/20
# 289/289 [==============================] - 25s 88ms/step - loss: 0.5759 - accuracy: 0.7682 - val_loss: 0.5362 - val_accuracy: 0.7933
# Epoch 4/20
# 289/289 [==============================] - 25s 86ms/step - loss: 0.4652 - accuracy: 0.8332 - val_loss: 0.4521 - val_accuracy: 0.8383
# Epoch 5/20
# 289/289 [==============================] - 26s 88ms/step - loss: 0.3571 - accuracy: 0.8766 - val_loss: 0.4046 - val_accuracy: 0.8529
# Epoch 6/20
# 289/289 [==============================] - 25s 88ms/step - loss: 0.2769 - accuracy: 0.9039 - val_loss: 0.3714 - val_accuracy: 0.8675
# Epoch 7/20
# 289/289 [==============================] - 25s 85ms/step - loss: 0.2220 - accuracy: 0.9270 - val_loss: 0.3538 - val_accuracy: 0.8751
# Epoch 8/20
# 289/289 [==============================] - 24s 83ms/step - loss: 0.1815 - accuracy: 0.9391 - val_loss: 0.3556 - val_accuracy: 0.8736
# Epoch 9/20
# 289/289 [==============================] - 23s 79ms/step - loss: 0.1492 - accuracy: 0.9514 - val_loss: 0.3553 - val_accuracy: 0.8698
# Epoch 9: early stopping

# %%
def create_model():
    model = Sequential()
    model.add(Embedding(max_features_tokenize, embed_dim, input_length=X.shape[1]))
    model.add(LSTM(units, dropout=0.5))
    model.add(Dense(3, activation='softmax'))
    adam = optimizers.Adam(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

def train_model(model, data_train, target_train, data_test, target_test):
    #es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2) #Diganti dan tidak usah dipakai pada model kedua
    history = model.fit(data_train, target_train, epochs=8, batch_size=32, 
                        validation_data=(data_test, target_test), verbose=1)
    return model, history

# Inisialisasi KFold
kf = KFold(n_splits=5, random_state=42, shuffle=True)
accuracies = []


embed_dim = 100
units = 64

# Iterasi melalui lipatan (folds) KFold
for iteration, data in enumerate(kf.split(X), start=1):
    data_train, target_train = X[data[0]], y[data[0]]
    data_test, target_test = X[data[1]], y[data[1]]

    model = create_model()
    trained_model, history = train_model(model, data_train, target_train, data_test, target_test)

    # Prediksi
    predictions = trained_model.predict(x_test)
    y_pred = predictions

    # Menghitung akurasi
    accuracy = accuracy_score(y_test.argmax(axis=1), y_pred.argmax(axis=1))

    # Menampilkan hasil
    print(f"Iterasi ke-{iteration}")
    print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1)))
    print("======================================================")

    accuracies.append(accuracy)

# Menghitung rata-rata akurasi
average_accuracy = np.mean(accuracies)

print("\n\n\n")
print("Rata-rata Akurasi:", round(average_accuracy, 4))
# Out:
# Epoch 1/8
# 331/331 [==============================] - 33s 92ms/step - loss: 0.9309 - accuracy: 0.5765 - val_loss: 0.7875 - val_accuracy: 0.6609
# Epoch 2/8
# 331/331 [==============================] - 28s 84ms/step - loss: 0.7117 - accuracy: 0.6747 - val_loss: 0.6589 - val_accuracy: 0.6787
# Epoch 3/8
# 331/331 [==============================] - 29s 88ms/step - loss: 0.6170 - accuracy: 0.7128 - val_loss: 0.5773 - val_accuracy: 0.7684
# Epoch 4/8
# 331/331 [==============================] - 28s 86ms/step - loss: 0.5269 - accuracy: 0.7961 - val_loss: 0.4969 - val_accuracy: 0.8164
# Epoch 5/8
# 331/331 [==============================] - 28s 85ms/step - loss: 0.4331 - accuracy: 0.8418 - val_loss: 0.4401 - val_accuracy: 0.8388
# Epoch 6/8
# 331/331 [==============================] - 29s 89ms/step - loss: 0.3602 - accuracy: 0.8698 - val_loss: 0.4134 - val_accuracy: 0.8478
# Epoch 7/8
# 331/331 [==============================] - 28s 86ms/step - loss: 0.3036 - accuracy: 0.8898 - val_loss: 0.3849 - val_accuracy: 0.8554
# Epoch 8/8
# 331/331 [==============================] - 28s 86ms/step - loss: 0.2614 - accuracy: 0.9050 - val_loss: 0.3690 - val_accuracy: 0.8596
# 124/124 [==============================] - 2s 9ms/step
# Iterasi ke-1
#               precision    recall  f1-score   support
#
#            0       0.73      0.87      0.79      1040
#            1       0.93      0.91      0.92       958
#            2       0.95      0.86      0.91      1965
#
#     accuracy                           0.88      3963
#    macro avg       0.87      0.88      0.87      3963
# weighted avg       0.89      0.88      0.88      3963
#
# ======================================================
# Epoch 1/8
# 331/331 [==============================] - 33s 92ms/step - loss: 0.9243 - accuracy: 0.5773 - val_loss: 0.7732 - val_accuracy: 0.6590
# Epoch 2/8
# 331/331 [==============================] - 28s 84ms/step - loss: 0.6977 - accuracy: 0.6789 - val_loss: 0.6630 - val_accuracy: 0.6715
# Epoch 3/8
# 331/331 [==============================] - 29s 87ms/step - loss: 0.6074 - accuracy: 0.7327 - val_loss: 0.5791 - val_accuracy: 0.7824
# Epoch 4/8
# 331/331 [==============================] - 29s 87ms/step - loss: 0.5133 - accuracy: 0.8018 - val_loss: 0.5089 - val_accuracy: 0.8168
# Epoch 5/8
# 331/331 [==============================] - 29s 88ms/step - loss: 0.4316 - accuracy: 0.8436 - val_loss: 0.4528 - val_accuracy: 0.8319
# Epoch 6/8
# 331/331 [==============================] - 29s 87ms/step - loss: 0.3615 - accuracy: 0.8716 - val_loss: 0.4172 - val_accuracy: 0.8460
# Epoch 7/8
# 331/331 [==============================] - 29s 87ms/step - loss: 0.3103 - accuracy: 0.8925 - val_loss: 0.3961 - val_accuracy: 0.8531
# Epoch 8/8
# 331/331 [==============================] - 29s 87ms/step - loss: 0.2631 - accuracy: 0.9092 - val_loss: 0.3740 - val_accuracy: 0.8603
# 124/124 [==============================] - 2s 9ms/step
# Iterasi ke-2
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83      1040
#            1       0.92      0.96      0.94       958
#            2       0.94      0.92      0.93      1965
#
#     accuracy                           0.91      3963
#    macro avg       0.90      0.91      0.90      3963
# weighted avg       0.91      0.91      0.91      3963
#
# ======================================================
# Epoch 1/8
# 331/331 [==============================] - 32s 89ms/step - loss: 0.9357 - accuracy: 0.5653 - val_loss: 0.7637 - val_accuracy: 0.6638
# Epoch 2/8
# 331/331 [==============================] - 28s 84ms/step - loss: 0.7040 - accuracy: 0.6795 - val_loss: 0.6461 - val_accuracy: 0.6819
# Epoch 3/8
# 331/331 [==============================] - 28s 86ms/step - loss: 0.6003 - accuracy: 0.7503 - val_loss: 0.5679 - val_accuracy: 0.7929
# Epoch 4/8
# 331/331 [==============================] - 29s 87ms/step - loss: 0.5095 - accuracy: 0.8154 - val_loss: 0.4954 - val_accuracy: 0.8254
# Epoch 5/8
# 331/331 [==============================] - 29s 87ms/step - loss: 0.4164 - accuracy: 0.8524 - val_loss: 0.4316 - val_accuracy: 0.8455
# Epoch 6/8
# 331/331 [==============================] - 28s 86ms/step - loss: 0.3430 - accuracy: 0.8802 - val_loss: 0.4127 - val_accuracy: 0.8413
# Epoch 7/8
# 331/331 [==============================] - 29s 87ms/step - loss: 0.2901 - accuracy: 0.8978 - val_loss: 0.3660 - val_accuracy: 0.8599
# Epoch 8/8
# 331/331 [==============================] - 29s 87ms/step - loss: 0.2490 - accuracy: 0.9131 - val_loss: 0.3567 - val_accuracy: 0.8694
# 124/124 [==============================] - 2s 10ms/step
# Iterasi ke-3
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89      1040
#            1       0.94      0.98      0.96       958
#            2       0.96      0.93      0.95      1965
#
#     accuracy                           0.93      3963
#    macro avg       0.93      0.94      0.93      3963
# weighted avg       0.93      0.93      0.93      3963
#
# ======================================================
# Epoch 1/8
# 331/331 [==============================] - 35s 99ms/step - loss: 0.9377 - accuracy: 0.5731 - val_loss: 0.8050 - val_accuracy: 0.6676
# Epoch 2/8
# 331/331 [==============================] - 29s 87ms/step - loss: 0.7119 - accuracy: 0.6762 - val_loss: 0.6682 - val_accuracy: 0.7130
# Epoch 3/8
# 331/331 [==============================] - 29s 86ms/step - loss: 0.6086 - accuracy: 0.7410 - val_loss: 0.5947 - val_accuracy: 0.7732
# Epoch 4/8
# 331/331 [==============================] - 28s 85ms/step - loss: 0.5233 - accuracy: 0.7946 - val_loss: 0.5279 - val_accuracy: 0.7864
# Epoch 5/8
# 331/331 [==============================] - 28s 86ms/step - loss: 0.4335 - accuracy: 0.8369 - val_loss: 0.4480 - val_accuracy: 0.8368
# Epoch 6/8
# 331/331 [==============================] - 29s 88ms/step - loss: 0.3589 - accuracy: 0.8698 - val_loss: 0.3987 - val_accuracy: 0.8603
# Epoch 7/8
# 331/331 [==============================] - 29s 86ms/step - loss: 0.3024 - accuracy: 0.8903 - val_loss: 0.3729 - val_accuracy: 0.8713
# Epoch 8/8
# 331/331 [==============================] - 28s 86ms/step - loss: 0.2575 - accuracy: 0.9094 - val_loss: 0.3519 - val_accuracy: 0.8796
# 124/124 [==============================] - 2s 9ms/step
# Iterasi ke-4
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1040
#            1       0.96      0.97      0.97       958
#            2       0.95      0.93      0.94      1965
#
#     accuracy                           0.93      3963
#    macro avg       0.92      0.93      0.93      3963
# weighted avg       0.93      0.93      0.93      3963
#
# ======================================================
# Epoch 1/8
# 331/331 [==============================] - 32s 89ms/step - loss: 0.9159 - accuracy: 0.5759 - val_loss: 0.7693 - val_accuracy: 0.6740
# Epoch 2/8
# 331/331 [==============================] - 29s 89ms/step - loss: 0.6964 - accuracy: 0.6777 - val_loss: 0.6545 - val_accuracy: 0.6925
# Epoch 3/8
# 331/331 [==============================] - 29s 89ms/step - loss: 0.6023 - accuracy: 0.7235 - val_loss: 0.5925 - val_accuracy: 0.7796
# Epoch 4/8
# 331/331 [==============================] - 29s 89ms/step - loss: 0.5155 - accuracy: 0.8031 - val_loss: 0.5203 - val_accuracy: 0.8054
# Epoch 5/8
# 331/331 [==============================] - 29s 88ms/step - loss: 0.4292 - accuracy: 0.8453 - val_loss: 0.4548 - val_accuracy: 0.8334
# Epoch 6/8
# 331/331 [==============================] - 31s 93ms/step - loss: 0.3509 - accuracy: 0.8740 - val_loss: 0.4165 - val_accuracy: 0.8523
# Epoch 7/8
# 331/331 [==============================] - 30s 91ms/step - loss: 0.2957 - accuracy: 0.8960 - val_loss: 0.3744 - val_accuracy: 0.8614
# Epoch 8/8
# 331/331 [==============================] - 30s 91ms/step - loss: 0.2476 - accuracy: 0.9112 - val_loss: 0.3686 - val_accuracy: 0.8679
# 124/124 [==============================] - 2s 10ms/step
# Iterasi ke-5
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1040
#            1       0.97      0.95      0.96       958
#            2       0.96      0.93      0.94      1965
#
#     accuracy                           0.93      3963
#    macro avg       0.92      0.93      0.93      3963
# weighted avg       0.93      0.93      0.93      3963
#
# ======================================================
#
#
#
#
# Rata-rata Akurasi: 0.915

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 6))

    # Plot Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'g', label='Training Acc')
    plt.plot(epochs, val_acc, 'y', label='Validation Acc')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    sns.despine()

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'g', label='Training Loss')
    plt.plot(epochs, val_loss, 'y', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    sns.despine()

    plt.tight_layout()
    plt.show()

# Memanggil fungsi plot_history untuk memvisualisasikan hasil
plot_history(history)

# %%
#Save model
trained_model.save('main_model.h5')
print('Model has created')
# Out:
# C:\Users\kenta\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model has created

# %%
input_text = """Dia memakan kue dengan lahap dan beringas jelek"""
def cleansing(text):
    text = text.lower()
    text = re.sub(r'((www\.[^\s]+)|(https?://[^\s]+)|(http?://[^\s]+))', ' ', text)
    text = re.sub(r'pic.twitter.com.[\w]+', ' ', text)
    text = re.sub(r'[^a-z\s]', ' ', text)
    text = text.replace('user', '')
    text = re.sub(' +', ' ', text)
    text = text.replace('\n', ' ')
    return text

sentiment = ['negative', 'neutral', 'positive']

text = [cleansing(input_text)]
predicted = data_tokenizer.texts_to_sequences(text)
guess = pad_sequences(predicted, maxlen=X.shape[1])

model = load_model('main_model.h5')
prediction = model.predict(guess)
polarity = np.argmax(prediction[0])
hasil = sentiment[polarity]

print("Text: %s" % text[0])
print("Sentiment: %s" % sentiment[polarity])
# Out:
# 1/1 [==============================] - 0s 371ms/step
# Text: dia memakan kue dengan lahap dan beringas jelek
# Sentiment: negative
